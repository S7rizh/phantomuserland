# %%
with open("isomem_dry_run.log") as f:
    text = f.read()

# %%
text
# Out:
# 'make -C phantom vm-isomem\nmake -C gl\n# FULL_FILE_PATH := specbuf.c\necho ---- cc {"target" : "specbuf.o", "file" : "specbuf.c" , "paths" : "/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/gl"}\ngcc -c -o specbuf.o -W -Wall -Wno-unused-parameter -Wno-sign-compare -m64 -O0 -g -MD  -I/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/gl -I/home/anton/Sandbox/PhantomOS/phantomuserland/include/genode_libc/libc -I/home/anton/Sandbox/PhantomOS/phantomuserland/include/genode_libc/libc -I/home/anton/Sandbox/PhantomOS/phantomuserland/include/genode_libc/spec/x86_64/libc -I/home/anton/Sandbox/PhantomOS/phantomuserland/include/genode_libc/spec/x86_64/libc -I/home/anton/Sandbox/PhantomOS/phantomuserland/include -I/home/anton/Sandbox/PhantomOS/phantomuserland/include/genode-amd64 -I/home/anton/Sandbox/PhantomOS/phantomuserland/include -I/home/anton/Sandbox/PhantomOS/phantomuserland/include/genode-amd64 -nostdinc -std=gnu89 -DKERNEL -DARCH_genode-amd64=1 -DBOARD_amd64-pc=1 -DBOARD=amd64-pc -include /home/anton/Sandbox/PhantomOS/phantomuserland/include/kernel/config.h -include /home/anton/Sandbox/PhantomOS/phantomuserland/include/genode-amd64/arch/arch-config.h -include /home/anton/Sandbox/PhantomOS/phantomuserland/include/genode-amd64/arch/board-amd64-pc-config.h  -fno-stack-protector -DPHANTOM_GENODE specbuf.c\n# FULL_FILE_PATH := phantom_loop.c\necho ---- cc {"target" : "phantom_loop.o", "file" : "phantom_loop.c" , "paths" : "/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/gl"}\ngcc -c -o phantom_loop.o -W -Wall -Wno-unused-parameter -Wno-sign-compare -m64 -O0 -g -MD  -I/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/gl -I/home/anton/Sandbox/PhantomOS/phantomuserland/include/genode_libc/libc -I/home/anton/Sandbox/PhantomOS/phantomuserland/include/genode_libc/libc -I/home/anton/Sandbox/PhantomOS/phantomuserland/include/genode_libc/spec/x86_64/libc -I/home/anton/Sandbox/PhantomOS/phantomuserland/include/genode_libc/spec/x86_64/libc -I/home/anton/Sandbox/PhantomOS/phantomuserland/include -I/home/anton/Sandbox/PhantomOS/phantomuserland/include/genode-amd64 -I/home/anton/Sandbox/PhantomOS/phantomuserland/include -I/home/anton/Sandbox/PhantomOS/phantomuserland/include/genode-amd64 -nostdinc -std=gnu89 -DKERNEL -DARCH_genode-amd64=1 -DBOARD_amd64-pc=1 -DBOARD=amd64-pc -include /home/anton/Sandbox/PhantomOS/phantomuserland/include/kernel/config.h -include /home/anton/Sandbox/PhantomOS/phantomuserland/include/genode-amd64/arch/arch-config.h -include /home/anton/Sandbox/PhantomOS/phantomuserland/include/genode-amd64/arch/board-amd64-pc-config.h  -fno-stack-protector -DPHANTOM_GENODE phantom_loop.c\n# FULL_FILE_PATH := list.c\necho ---- cc {"target" : "list.o", "file" : "list.c" , "paths" : "/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/gl"}\ngcc -c -o list.o -W -Wall -Wno-unused-parameter -Wno-sign-compare -m64 -O0 -g -MD  -I/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/gl -I/home/anton/Sandbox/PhantomOS/phantomuserland/include/genode_libc/libc -I/home/anton/Sandbox/PhantomOS/phantomuserland/include/genode_libc/libc -I/home/anton/Sandbox/PhantomOS/phantomuserland/include/genode_libc/spec/x86_64/libc -I/home/anton/Sandbox/PhantomOS/phantomuserland/include/genode_libc/spec/x86_64/libc -I/home/anton/Sandbox/PhantomOS/phantomuserland/include -I/home/anton/Sandbox/PhantomOS/phantomuserland/include/genode-amd64 -I/home/anton/Sandbox/PhantomOS/phantomuserland/include -I/home/anton/Sandbox/PhantomOS/phantomuserland/include/genode-amd64 -nostdinc -std=gnu89 -DKERNEL -DARCH_genode-amd64=1 -DBOARD_amd64-pc=1 -DBOARD=amd64-pc -include /home/anton/Sandbox/PhantomOS/phantomuserland/include/kernel/config.h -include /home/anton/Sandbox/PhantomOS/phantomuserland/include/genode-amd64/arch/arch-config.h -include /home/anton/Sandbox/PhantomOS/phantomuserland/include/genode-amd64/arch/board-amd64-pc-config.h  -fno-stack-protector -DPHANTOM_GENODE list.c\n# FULL_FILE_PATH := error.c\necho ---- cc {"target" : "error.o", "file" : "er ...

# %%
import re

sections_raw = re.split(r"make -C (.*?)\n", text)

# %%
cc_lines = [x for x in text.split("\n") if x.startswith("echo ---- cc ")]
# print(cc_lines)

# %%
import json

cc_lines = [x[len("echo ---- cc "):] for x in cc_lines]

# %%
cc_lines = [x.strip() for x in cc_lines]
targets = [json.loads(x) for x in cc_lines]

# %%
len(targets)
# Out:
# 390

# %%
sections = list(zip(sections_raw[1::2], sections_raw[2::2]))

# %%
sections[0]
# Out:
# ('phantom/gl',
#  '# FULL_FILE_PATH := specbuf.c\necho ---- cc {"target" : "specbuf.o", "file" : "specbuf.c" , "paths" : "/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/gl"}\ngcc -c -o specbuf.o -W -Wall -Wno-unused-parameter -Wno-sign-compare -m32 -O0 -g -MD  -I/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/gl -I/home/anton/Sandbox/PhantomOS/phantomuserland/include -I/home/anton/Sandbox/PhantomOS/phantomuserland/include/ia32 -I/home/anton/Sandbox/PhantomOS/phantomuserland/include -I/home/anton/Sandbox/PhantomOS/phantomuserland/include/ia32 -nostdinc -std=gnu89 -DKERNEL -DARCH_ia32=1 -DBOARD_ia32_default=1 -DBOARD=ia32_default -include /home/anton/Sandbox/PhantomOS/phantomuserland/include/kernel/config.h -include /home/anton/Sandbox/PhantomOS/phantomuserland/include/ia32/arch/arch-config.h -include /home/anton/Sandbox/PhantomOS/phantomuserland/include/ia32/arch/board-ia32_default-config.h  -fno-stack-protector specbuf.c\n# FULL_FILE_PATH := phantom_loop.c\necho ---- cc {"target" : "phantom_loop.o", "file" : "phantom_loop.c" , "paths" : "/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/gl"}\ngcc -c -o phantom_loop.o -W -Wall -Wno-unused-parameter -Wno-sign-compare -m32 -O0 -g -MD  -I/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/gl -I/home/anton/Sandbox/PhantomOS/phantomuserland/include -I/home/anton/Sandbox/PhantomOS/phantomuserland/include/ia32 -I/home/anton/Sandbox/PhantomOS/phantomuserland/include -I/home/anton/Sandbox/PhantomOS/phantomuserland/include/ia32 -nostdinc -std=gnu89 -DKERNEL -DARCH_ia32=1 -DBOARD_ia32_default=1 -DBOARD=ia32_default -include /home/anton/Sandbox/PhantomOS/phantomuserland/include/kernel/config.h -include /home/anton/Sandbox/PhantomOS/phantomuserland/include/ia32/arch/arch-config.h -include /home/anton/Sandbox/PhantomOS/phantomuserland/include/ia32/arch/board-ia32_default-config.h  -fno-stack-protector phantom_loop.c\n# FULL_FILE_PATH := list.c\necho ---- cc {"target" : "list.o", "file" : "list.c" , "paths" : "/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/gl"}\ngcc -c -o list.o -W -Wall -Wno-unused-parameter -Wno-sign-compare -m32 -O0 -g -MD  -I/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/gl -I/home/anton/Sandbox/PhantomOS/phantomuserland/include -I/home/anton/Sandbox/PhantomOS/phantomuserland/include/ia32 -I/home/anton/Sandbox/PhantomOS/phantomuserland/include -I/home/anton/Sandbox/PhantomOS/phantomuserland/include/ia32 -nostdinc -std=gnu89 -DKERNEL -DARCH_ia32=1 -DBOARD_ia32_default=1 -DBOARD=ia32_default -include /home/anton/Sandbox/PhantomOS/phantomuserland/include/kernel/config.h -include /home/anton/Sandbox/PhantomOS/phantomuserland/include/ia32/arch/arch-config.h -include /home/anton/Sandbox/PhantomOS/phantomuserland/include/ia32/arch/board-ia32_default-config.h  -fno-stack-protector list.c\n# FULL_FILE_PATH := error.c\necho ---- cc {"target" : "error.o", "file" : "error.c" , "paths" : "/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/gl"}\ngcc -c -o error.o -W -Wall -Wno-unused-parameter -Wno-sign-compare -m32 -O0 -g -MD  -I/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/gl -I/home/anton/Sandbox/PhantomOS/phantomuserland/include -I/home/anton/Sandbox/PhantomOS/phantomuserland/include/ia32 -I/home/anton/Sandbox/PhantomOS/phantomuserland/include -I/home/anton/Sandbox/PhantomOS/phantomuserland/include/ia32 -nostdinc -std=gnu89 -DKERNEL -DARCH_ia32=1 -DBOARD_ia32_default=1 -DBOARD=ia32_default -include /home/anton/Sandbox/PhantomOS/phantomuserland/include/kernel/config.h -include /home/anton/Sandbox/PhantomOS/phantomuserland/include/ia32/arch/arch-config.h -include /home/anton/Sandbox/PhantomOS/phantomuserland/include/ia32/arch/board-ia32_default-config.h  -fno-stack-protector error.c\n# FULL_FILE_PATH := texture.c\necho ---- cc {"target" : "texture.o", "file" : "texture.c" , "paths" : "/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/gl"}\ngcc -c -o texture.o -W -Wall -Wno-unused-parameter -Wno-sign-compare -m32 -O0 -g -MD  -I/home/anton/Sandbox/Phantom ...

# %%
# # for s in section:
# s = sections[0]
# cc_lines = [x for x in s[1].split("\n") if x.startswith("echo ---- cc ")]
# cc_lines = [x[len("echo ---- cc "):] for x in cc_lines]
# targets = [json.loads(x) for x in cc_lines]

# %%
# import os

# valid_paths = []

# for t in targets:
#     paths = [os.path.join(s, t["file"]) for s in t["paths"].split(" ")]
#     valid_paths.append((paths, [os.path.exists(x) for x in paths]))

# %%
# # Simple check
# for v in valid_paths:
#     print(v)
#     if v[1].count(True) != 1:
#         print("------ " + str(v[1].count(True)))
#         print(v[0])

# %%
import os

files_per_section = []

for s in sections:
    cc_lines = [x for x in s[1].split("\n") if x.startswith("echo ---- cc ")]
    cc_lines = [x[len("echo ---- cc "):] for x in cc_lines]
    targets = [json.loads(x) for x in cc_lines]
    
    valid_paths = []

    for t in targets:
        paths = list(set([os.path.join(s, t["file"]) for s in t["paths"].split(" ")]))
        valid_paths.append((paths, [os.path.exists(x) for x in paths]))
    
    current_files_list = []
    
    # Simple 
    print("######  " + str(s[0]))
    for v in valid_paths:
#         print(v)
        if v[1].count(True) != 1:
            # Something went wrong if you are in this block
            print("------ " + str(v[1].count(True)))
#             print(v[0])
            print("Trying using set()")
            unique_values = set(v[0])
            if (len(unique_values) != 1):
                print("Didn't work. Values={}".format(v[0]))
            else:
                print("Worked :)")
        else:
            current_files_list.append(v[0][v[1].index(True)])
    
    files_per_section.append((s[0], current_files_list))
# Out:
# ######  phantom vm-isomem
# ######  gl
# ######  libtuned
# ######  libphantom
# ######  libwin
# ######  libfreetype
# ######  vm
# ######  vm pvm_headless_screen
# ######  isomem
# ######  isomem pvm_isomem

# %%
files_per_section
# Out:
# [('phantom vm-isomem', []),
#  ('gl',
#   ['/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/gl/specbuf.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/gl/phantom_loop.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/gl/list.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/gl/error.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/gl/texture.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/gl/select.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/gl/init.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/gl/light.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/gl/arrays.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/gl/vertex.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/gl/oscontext.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/gl/image_util.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/gl/clip.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/gl/phantomdrvr.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/gl/api.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/gl/misc.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/gl/memory.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/gl/clear.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/gl/zdither.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/gl/msghandling.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/gl/ztriangle.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/gl/zline.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/gl/zmath.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/gl/zbuffer.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/gl/matrix.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/gl/texobj.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/gl/get.c']),
#  ('libtuned', []),
#  ('libphantom',
#   ['/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libphantom/console_color.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libphantom/wired_spin.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libphantom/udp_json_builder.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libphantom/atoin.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libphantom/init.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libphantom/i_disk.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libphantom/hashfunc.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libphantom/udp_json.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libphantom/pool.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libphantom/hexdump.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libphantom/json_read.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libphantom/asn1.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libphantom/atoln.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libphantom/unicode2utf8.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libphantom/disk_struct.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libphantom/debug.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libphantom/symtab.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libphantom/jsmn.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libphantom/stats.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libphantom/json_write.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libphantom/http.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libphantom/wtty.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libphantom/video/color.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libphantom/lzma/LzmaDec.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libphantom/lzma/simpleDecode.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libphantom/unix/fname.c']),
#  ('libwin',
#   ['/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/w_control.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/vid_read.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/scr_getset.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/w_decor.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/ev_window.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/w_getset.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/w_create.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/w_scroll.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/ev_main.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/vid_write.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/ev_mouse.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/bmp_pbm.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/rgba_bitblt_bits.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/scr_repaint.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/rgba_const.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/w_move_z.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/w_dump.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/rect_cmp.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/ctl_button.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/rgba_scroll.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/w_bg_win.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/w_lock.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/ctl_getset.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/ev_wtty.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/ev_put.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/vid_blt_wrap.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/w_truetype.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/scr_zbuf.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/w_resize.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/w_draw.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/w_repaint.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/w_menu.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/utf8proc.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/scr_painter.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/w_taskbar.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/ctl_create.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/scr_mouse_onoff.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/vid_mouse_pointer.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/rgba_zbmove.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/ctl_scrollbar.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/w_move_xy.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/ctl_text_field.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/w_replicate.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/w_blt.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/w_box.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/w_font.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/w_event_client.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/w_event_title.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/w_order.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/rgba_ablend_bits.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/w_update.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/ev_util.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/rgba_hsb.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/OpenSans-Light.ttf.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/button_next_green_full_alpha_x65.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/RobotoMono-ThinItalic.ttf.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/win_decor_dl.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/vanilla_cream_rollup.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/menu_normal_center.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/checkbox_round_on_a_x30.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/toolbar_icon_calendar_normal.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/RobotoMono-Italic.ttf.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/toolbar_icon_calendar_hover.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/task_button.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/OpenSans-Bold.ttf.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/button_prev_green_alpha_x65.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/power_button_sm.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/icon_heart.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/scrollbar_orange_bar_right.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/win_decor_ul.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/OpenSans-SemiBoldItalic.ttf.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/toolbar_icon_shell_pressed.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/checkbox_square_on_a_x30.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/scrollbar_orange_bar_middle.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/toolbar_icon_settings_pressed.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/rollup_pressed.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/menu_selected_center.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/slide_switch_alpha_v31_off.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/toolbar_icon_calendar_selected.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/icon_key.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/close_pressed.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/OpenSans-SemiBold.ttf.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/button_prev_green_full_alpha_x65.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/scrollbar_bed_right.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/slide_switch_off.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/vanilla_cream_close.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/scrollbar_orange_bar_left.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/scrollbar_bed_middle_narrow.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/OpenSans-ExtraBoldItalic.ttf.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/RobotoMono-Light.ttf.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/button_normal_alpha_x98_abw.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/start_button_hover.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/RobotoMono-LightItalic.ttf.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/icon_conversation.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/button_pressed_alpha_x98.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/toolbar_icon_debug_hover.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/win_decor_dr.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/menu_normal_left.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/text_field_icon_x160.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/title_brown.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/RobotoMono-Medium.ttf.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/RobotoMono-Bold.ttf.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/button_next_green_alpha_x65.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/title_selected.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/checkbox_round_off_a_x30.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/small_popup_note.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/title_green.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/button_prev_alpha_x82.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/icon_settings.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/slide_switch_alpha_v31_on.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/power_button_pressed_sm.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/scroll_bar_green_handle.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/title_violet.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/menu_selected_left.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/scrollbar_green_bar_right.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/pin.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/win_decor_ur.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/toolbar_icon_selected.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/scrollbar_green_bar_left.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/OpenSans-BoldItalic.ttf.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/notification_green_button.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/toolbar_icon_calendar_pressed.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/scrollbar_bed_middle.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/OpenSans-Regular.ttf.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/toolbar_icon_settings_normal.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/rollup.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/toolbar_icon_settings_hover.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/toolbar_icon_debug_normal.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/menu_normal_right.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/checkbox_square_off_a_x30.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/toolbar_icon_shell_normal.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/button_center_white_for_green_alpha_x169.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/RobotoMono-Thin.ttf.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/RobotoMono-Regular.ttf.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/button_hover_alpha_x98.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/title_deselected.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/button_next_alpha_x82.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/toolbar_icon_shell_selected.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/start_button_selected_w_key.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/toolbar_icon_settings_selected.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/text_field_x200.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/start_button_selected.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/button_normal_alpha_x98.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/OpenSans-ExtraBold.ttf.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/OpenSans-Italic.ttf.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/menu_selected_right.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/button_pressed_alpha_x98_abw.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/scrollbar_green_bar_middle.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/RobotoMono-MediumItalic.ttf.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/close.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/icon_text.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/button_hover_alpha_x98_abw.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/vanilla_background.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/win_decor_ljoin.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/toolbar_icon_debug_pressed.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/RobotoMono-BoldItalic.ttf.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/icon_home.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/win_decor_rjoin.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/icon_plus.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/OpenSans-LightItalic.ttf.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/start_button_normal.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/toolbar_icon_shell_hover.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/slide_switch_on.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/icon_screen.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/resources/scrollbar_bed_left.png.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/fonts/drv_video_kolibri2.fnt.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/fonts/drv_video_8x16san.fnt.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/fonts/drv_video_8x16cou.fnt.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/fonts/drv_video_16x16.fnt.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/fonts/freebsd_font.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/fonts/drv_video_8x16med.fnt.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/fonts/gallant12x22.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/fonts/drv_video_8x16bro.fnt.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/fonts/drv_video_8x16rom.fnt.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/fonts/drv_video_8x16scr.fnt.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/fonts/drv_video_kolibri1.fnt.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/fonts/drv_video_8x16ant.fnt.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/fonts/8x11.fnt.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libwin/mice/default_mouse.c']),
#  ('libfreetype',
#   ['/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libfreetype/sfnt.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libfreetype/ttgload.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libfreetype/ftutil.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libfreetype/ttcmap.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libfreetype/ftoutln.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libfreetype/ttsbit.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libfreetype/ftbitmap.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libfreetype/ttpost.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libfreetype/ftstream.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libfreetype/ftsystem.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libfreetype/smooth.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libfreetype/ttgxvar.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libfreetype/ftinit.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libfreetype/ftrfork.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libfreetype/truetype.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libfreetype/ftdebug.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libfreetype/ftsmooth.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libfreetype/afdummy.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libfreetype/ftobjs.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libfreetype/ftgloadr.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libfreetype/ftbase.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libfreetype/afglobal.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libfreetype/afhints.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libfreetype/ftdbgmem.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libfreetype/sfobjs.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libfreetype/sfdriver.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libfreetype/afloader.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libfreetype/autofit.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libfreetype/fttrigon.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libfreetype/ftnames.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libfreetype/ttkern.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libfreetype/ttobjs.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libfreetype/afmodule.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libfreetype/ttload.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libfreetype/afangles.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libfreetype/aflatin.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libfreetype/ftcalc.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libfreetype/ftgrays.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libfreetype/ttdriver.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libfreetype/ftglyph.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/libfreetype/ttpload.c']),
#  ('vm',
#   ['/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/vm/exec.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/vm/syscall_io.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/vm/backtrace.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/vm/syscall_sync.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/vm/refdec.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/vm/gen_machindep.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/vm/syscall.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/vm/json_parse.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/vm/gdb.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/vm/vm_sleep.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/vm/e4c.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/vm/stacks.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/vm/wpool.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/vm/code.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/vm/root.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/vm/syscall_net_kernel.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/vm/vtest.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/vm/syscall_win.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/vm/create.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/vm/load_class.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/vm/ftype.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/vm/video_test.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/vm/syscall_tty.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/vm/object.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/vm/alloc.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/vm/syscall_net_windows.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/vm/find_class_file.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/vm/vm_threads.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/vm/jit.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/vm/internal.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/vm/bulk.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/vm/gc.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/vm/wpaint.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/vm/syscall_net.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/vm/directory.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/vm/sys/i_stat.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/vm/sys/i_udp.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/vm/sys/i_time.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/vm/sys/i_ui_control.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/vm/sys/i_io.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/vm/sys/i_ui_font.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/vm/sys/i_port.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/vm/sys/i_http.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/vm/sys/i_net.c']),
#  ('vm pvm_headless_screen',
#   ['/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/vm/headless_screen.c']),
#  ('isomem',
#   ['/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/khash.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/udp_json.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/vm_cn_stats.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/unix_hal_sync.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/pool.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/unix_hal.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/temp_loader_misc.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/test_mem.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/hexdump.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/genode_credentials.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/genode_timer.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/vm_connect.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/genode_paging.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/test_switch.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/vm_load.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/fs_map.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/vm_map.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/hal_interrupts.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/vm_cn_fio.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/dpc.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/test_hdir.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/json_read.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/boot_cmd_line.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/genode_lprintf.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/main.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/genode_atomic.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/disk_struct.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/hashfunc.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/timedcall.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/genode_physalloc.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/pager.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/ide_io.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/genode_user_trap.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/hal.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/unix_threads.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/fsck.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/net_timer.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/unix_sys.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/disk.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/json_write.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/color.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/test_misc.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/pagelist.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/debug_misc.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/driver_pci_intel_etc.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/genode_kunix.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/unix_hal_unix.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/test_pool.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/vm_cn_url.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/genode_misc.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/disk_pool.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/physalloc.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/snap_sync.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/stats.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/genode_arch.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/syscalls_misc.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/time.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/test_disk.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/temp_wtty.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/vm_cn_timer.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/genode_time.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/amap.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/init_funcs.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/hal_physmem.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/test_amap.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/genode_gdb_cmd_stub.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/genode_net.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/genode_intrdisp.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/init.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/vm_cn_udp.c',
#    '/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/genode_disk.c']),
#  ('isomem pvm_isomem',
#   ['/home/anton/Sandbox/PhantomOS/phantomuserland/phantom/isomem/main.c'])]

# %%
# Ok, now need to normalize and transform paths. so we can use them in Genode

# %%
PHANTOM_HOME = "/home/anton/Sandbox/PhantomOS/phantomuserland"

norm_files_per_section = [(x[0], [os.path.relpath(os.path.normpath(t), PHANTOM_HOME) for t in x[1]]) for x in files_per_section]

# %%
norm_files_per_section
# Out:
# [('phantom vm-isomem', []),
#  ('gl',
#   ['phantom/gl/specbuf.c',
#    'phantom/gl/phantom_loop.c',
#    'phantom/gl/list.c',
#    'phantom/gl/error.c',
#    'phantom/gl/texture.c',
#    'phantom/gl/select.c',
#    'phantom/gl/init.c',
#    'phantom/gl/light.c',
#    'phantom/gl/arrays.c',
#    'phantom/gl/vertex.c',
#    'phantom/gl/oscontext.c',
#    'phantom/gl/image_util.c',
#    'phantom/gl/clip.c',
#    'phantom/gl/phantomdrvr.c',
#    'phantom/gl/api.c',
#    'phantom/gl/misc.c',
#    'phantom/gl/memory.c',
#    'phantom/gl/clear.c',
#    'phantom/gl/zdither.c',
#    'phantom/gl/msghandling.c',
#    'phantom/gl/ztriangle.c',
#    'phantom/gl/zline.c',
#    'phantom/gl/zmath.c',
#    'phantom/gl/zbuffer.c',
#    'phantom/gl/matrix.c',
#    'phantom/gl/texobj.c',
#    'phantom/gl/get.c']),
#  ('libtuned', []),
#  ('libphantom',
#   ['phantom/libphantom/console_color.c',
#    'phantom/libphantom/wired_spin.c',
#    'phantom/libphantom/udp_json_builder.c',
#    'phantom/libphantom/atoin.c',
#    'phantom/libphantom/init.c',
#    'phantom/libphantom/i_disk.c',
#    'phantom/libphantom/hashfunc.c',
#    'phantom/libphantom/udp_json.c',
#    'phantom/libphantom/pool.c',
#    'phantom/libphantom/hexdump.c',
#    'phantom/libphantom/json_read.c',
#    'phantom/libphantom/asn1.c',
#    'phantom/libphantom/atoln.c',
#    'phantom/libphantom/unicode2utf8.c',
#    'phantom/libphantom/disk_struct.c',
#    'phantom/libphantom/debug.c',
#    'phantom/libphantom/symtab.c',
#    'phantom/libphantom/jsmn.c',
#    'phantom/libphantom/stats.c',
#    'phantom/libphantom/json_write.c',
#    'phantom/libphantom/http.c',
#    'phantom/libphantom/wtty.c',
#    'phantom/libphantom/video/color.c',
#    'phantom/libphantom/lzma/LzmaDec.c',
#    'phantom/libphantom/lzma/simpleDecode.c',
#    'phantom/libphantom/unix/fname.c']),
#  ('libwin',
#   ['phantom/libwin/w_control.c',
#    'phantom/libwin/vid_read.c',
#    'phantom/libwin/scr_getset.c',
#    'phantom/libwin/w_decor.c',
#    'phantom/libwin/ev_window.c',
#    'phantom/libwin/w_getset.c',
#    'phantom/libwin/w_create.c',
#    'phantom/libwin/w_scroll.c',
#    'phantom/libwin/ev_main.c',
#    'phantom/libwin/vid_write.c',
#    'phantom/libwin/ev_mouse.c',
#    'phantom/libwin/bmp_pbm.c',
#    'phantom/libwin/rgba_bitblt_bits.c',
#    'phantom/libwin/scr_repaint.c',
#    'phantom/libwin/rgba_const.c',
#    'phantom/libwin/w_move_z.c',
#    'phantom/libwin/w_dump.c',
#    'phantom/libwin/rect_cmp.c',
#    'phantom/libwin/ctl_button.c',
#    'phantom/libwin/rgba_scroll.c',
#    'phantom/libwin/w_bg_win.c',
#    'phantom/libwin/w_lock.c',
#    'phantom/libwin/ctl_getset.c',
#    'phantom/libwin/ev_wtty.c',
#    'phantom/libwin/ev_put.c',
#    'phantom/libwin/vid_blt_wrap.c',
#    'phantom/libwin/w_truetype.c',
#    'phantom/libwin/scr_zbuf.c',
#    'phantom/libwin/w_resize.c',
#    'phantom/libwin/w_draw.c',
#    'phantom/libwin/w_repaint.c',
#    'phantom/libwin/w_menu.c',
#    'phantom/libwin/utf8proc.c',
#    'phantom/libwin/scr_painter.c',
#    'phantom/libwin/w_taskbar.c',
#    'phantom/libwin/ctl_create.c',
#    'phantom/libwin/scr_mouse_onoff.c',
#    'phantom/libwin/vid_mouse_pointer.c',
#    'phantom/libwin/rgba_zbmove.c',
#    'phantom/libwin/ctl_scrollbar.c',
#    'phantom/libwin/w_move_xy.c',
#    'phantom/libwin/ctl_text_field.c',
#    'phantom/libwin/w_replicate.c',
#    'phantom/libwin/w_blt.c',
#    'phantom/libwin/w_box.c',
#    'phantom/libwin/w_font.c',
#    'phantom/libwin/w_event_client.c',
#    'phantom/libwin/w_event_title.c',
#    'phantom/libwin/w_order.c',
#    'phantom/libwin/rgba_ablend_bits.c',
#    'phantom/libwin/w_update.c',
#    'phantom/libwin/ev_util.c',
#    'phantom/libwin/rgba_hsb.c',
#    'phantom/libwin/resources/OpenSans-Light.ttf.c',
#    'phantom/libwin/resources/button_next_green_full_alpha_x65.png.c',
#    'phantom/libwin/resources/RobotoMono-ThinItalic.ttf.c',
#    'phantom/libwin/resources/win_decor_dl.png.c',
#    'phantom/libwin/resources/vanilla_cream_rollup.png.c',
#    'phantom/libwin/resources/menu_normal_center.png.c',
#    'phantom/libwin/resources/checkbox_round_on_a_x30.png.c',
#    'phantom/libwin/resources/toolbar_icon_calendar_normal.png.c',
#    'phantom/libwin/resources/RobotoMono-Italic.ttf.c',
#    'phantom/libwin/resources/toolbar_icon_calendar_hover.png.c',
#    'phantom/libwin/resources/task_button.png.c',
#    'phantom/libwin/resources/OpenSans-Bold.ttf.c',
#    'phantom/libwin/resources/button_prev_green_alpha_x65.png.c',
#    'phantom/libwin/resources/power_button_sm.png.c',
#    'phantom/libwin/resources/icon_heart.png.c',
#    'phantom/libwin/resources/scrollbar_orange_bar_right.png.c',
#    'phantom/libwin/resources/win_decor_ul.png.c',
#    'phantom/libwin/resources/OpenSans-SemiBoldItalic.ttf.c',
#    'phantom/libwin/resources/toolbar_icon_shell_pressed.png.c',
#    'phantom/libwin/resources/checkbox_square_on_a_x30.png.c',
#    'phantom/libwin/resources/scrollbar_orange_bar_middle.png.c',
#    'phantom/libwin/resources/toolbar_icon_settings_pressed.png.c',
#    'phantom/libwin/resources/rollup_pressed.png.c',
#    'phantom/libwin/resources/menu_selected_center.png.c',
#    'phantom/libwin/resources/slide_switch_alpha_v31_off.png.c',
#    'phantom/libwin/resources/toolbar_icon_calendar_selected.png.c',
#    'phantom/libwin/resources/icon_key.png.c',
#    'phantom/libwin/resources/close_pressed.png.c',
#    'phantom/libwin/resources/OpenSans-SemiBold.ttf.c',
#    'phantom/libwin/resources/button_prev_green_full_alpha_x65.png.c',
#    'phantom/libwin/resources/scrollbar_bed_right.png.c',
#    'phantom/libwin/resources/slide_switch_off.png.c',
#    'phantom/libwin/resources/vanilla_cream_close.png.c',
#    'phantom/libwin/resources/scrollbar_orange_bar_left.png.c',
#    'phantom/libwin/resources/scrollbar_bed_middle_narrow.png.c',
#    'phantom/libwin/resources/OpenSans-ExtraBoldItalic.ttf.c',
#    'phantom/libwin/resources/RobotoMono-Light.ttf.c',
#    'phantom/libwin/resources/button_normal_alpha_x98_abw.png.c',
#    'phantom/libwin/resources/start_button_hover.png.c',
#    'phantom/libwin/resources/RobotoMono-LightItalic.ttf.c',
#    'phantom/libwin/resources/icon_conversation.png.c',
#    'phantom/libwin/resources/button_pressed_alpha_x98.png.c',
#    'phantom/libwin/resources/toolbar_icon_debug_hover.png.c',
#    'phantom/libwin/resources/win_decor_dr.png.c',
#    'phantom/libwin/resources/menu_normal_left.png.c',
#    'phantom/libwin/resources/text_field_icon_x160.png.c',
#    'phantom/libwin/resources/title_brown.png.c',
#    'phantom/libwin/resources/RobotoMono-Medium.ttf.c',
#    'phantom/libwin/resources/RobotoMono-Bold.ttf.c',
#    'phantom/libwin/resources/button_next_green_alpha_x65.png.c',
#    'phantom/libwin/resources/title_selected.png.c',
#    'phantom/libwin/resources/checkbox_round_off_a_x30.png.c',
#    'phantom/libwin/resources/small_popup_note.png.c',
#    'phantom/libwin/resources/title_green.png.c',
#    'phantom/libwin/resources/button_prev_alpha_x82.png.c',
#    'phantom/libwin/resources/icon_settings.png.c',
#    'phantom/libwin/resources/slide_switch_alpha_v31_on.png.c',
#    'phantom/libwin/resources/power_button_pressed_sm.png.c',
#    'phantom/libwin/resources/scroll_bar_green_handle.png.c',
#    'phantom/libwin/resources/title_violet.png.c',
#    'phantom/libwin/resources/menu_selected_left.png.c',
#    'phantom/libwin/resources/scrollbar_green_bar_right.png.c',
#    'phantom/libwin/resources/pin.png.c',
#    'phantom/libwin/resources/win_decor_ur.png.c',
#    'phantom/libwin/resources/toolbar_icon_selected.png.c',
#    'phantom/libwin/resources/scrollbar_green_bar_left.png.c',
#    'phantom/libwin/resources/OpenSans-BoldItalic.ttf.c',
#    'phantom/libwin/resources/notification_green_button.png.c',
#    'phantom/libwin/resources/toolbar_icon_calendar_pressed.png.c',
#    'phantom/libwin/resources/scrollbar_bed_middle.png.c',
#    'phantom/libwin/resources/OpenSans-Regular.ttf.c',
#    'phantom/libwin/resources/toolbar_icon_settings_normal.png.c',
#    'phantom/libwin/resources/rollup.png.c',
#    'phantom/libwin/resources/toolbar_icon_settings_hover.png.c',
#    'phantom/libwin/resources/toolbar_icon_debug_normal.png.c',
#    'phantom/libwin/resources/menu_normal_right.png.c',
#    'phantom/libwin/resources/checkbox_square_off_a_x30.png.c',
#    'phantom/libwin/resources/toolbar_icon_shell_normal.png.c',
#    'phantom/libwin/resources/button_center_white_for_green_alpha_x169.png.c',
#    'phantom/libwin/resources/RobotoMono-Thin.ttf.c',
#    'phantom/libwin/resources/RobotoMono-Regular.ttf.c',
#    'phantom/libwin/resources/button_hover_alpha_x98.png.c',
#    'phantom/libwin/resources/title_deselected.png.c',
#    'phantom/libwin/resources/button_next_alpha_x82.png.c',
#    'phantom/libwin/resources/toolbar_icon_shell_selected.png.c',
#    'phantom/libwin/resources/start_button_selected_w_key.png.c',
#    'phantom/libwin/resources/toolbar_icon_settings_selected.png.c',
#    'phantom/libwin/resources/text_field_x200.png.c',
#    'phantom/libwin/resources/start_button_selected.png.c',
#    'phantom/libwin/resources/button_normal_alpha_x98.png.c',
#    'phantom/libwin/resources/OpenSans-ExtraBold.ttf.c',
#    'phantom/libwin/resources/OpenSans-Italic.ttf.c',
#    'phantom/libwin/resources/menu_selected_right.png.c',
#    'phantom/libwin/resources/button_pressed_alpha_x98_abw.png.c',
#    'phantom/libwin/resources/scrollbar_green_bar_middle.png.c',
#    'phantom/libwin/resources/RobotoMono-MediumItalic.ttf.c',
#    'phantom/libwin/resources/close.png.c',
#    'phantom/libwin/resources/icon_text.png.c',
#    'phantom/libwin/resources/button_hover_alpha_x98_abw.png.c',
#    'phantom/libwin/resources/vanilla_background.png.c',
#    'phantom/libwin/resources/win_decor_ljoin.png.c',
#    'phantom/libwin/resources/toolbar_icon_debug_pressed.png.c',
#    'phantom/libwin/resources/RobotoMono-BoldItalic.ttf.c',
#    'phantom/libwin/resources/icon_home.png.c',
#    'phantom/libwin/resources/win_decor_rjoin.png.c',
#    'phantom/libwin/resources/icon_plus.png.c',
#    'phantom/libwin/resources/OpenSans-LightItalic.ttf.c',
#    'phantom/libwin/resources/start_button_normal.png.c',
#    'phantom/libwin/resources/toolbar_icon_shell_hover.png.c',
#    'phantom/libwin/resources/slide_switch_on.png.c',
#    'phantom/libwin/resources/icon_screen.png.c',
#    'phantom/libwin/resources/scrollbar_bed_left.png.c',
#    'phantom/libwin/fonts/drv_video_kolibri2.fnt.c',
#    'phantom/libwin/fonts/drv_video_8x16san.fnt.c',
#    'phantom/libwin/fonts/drv_video_8x16cou.fnt.c',
#    'phantom/libwin/fonts/drv_video_16x16.fnt.c',
#    'phantom/libwin/fonts/freebsd_font.c',
#    'phantom/libwin/fonts/drv_video_8x16med.fnt.c',
#    'phantom/libwin/fonts/gallant12x22.c',
#    'phantom/libwin/fonts/drv_video_8x16bro.fnt.c',
#    'phantom/libwin/fonts/drv_video_8x16rom.fnt.c',
#    'phantom/libwin/fonts/drv_video_8x16scr.fnt.c',
#    'phantom/libwin/fonts/drv_video_kolibri1.fnt.c',
#    'phantom/libwin/fonts/drv_video_8x16ant.fnt.c',
#    'phantom/libwin/fonts/8x11.fnt.c',
#    'phantom/libwin/mice/default_mouse.c']),
#  ('libfreetype',
#   ['phantom/libfreetype/sfnt.c',
#    'phantom/libfreetype/ttgload.c',
#    'phantom/libfreetype/ftutil.c',
#    'phantom/libfreetype/ttcmap.c',
#    'phantom/libfreetype/ftoutln.c',
#    'phantom/libfreetype/ttsbit.c',
#    'phantom/libfreetype/ftbitmap.c',
#    'phantom/libfreetype/ttpost.c',
#    'phantom/libfreetype/ftstream.c',
#    'phantom/libfreetype/ftsystem.c',
#    'phantom/libfreetype/smooth.c',
#    'phantom/libfreetype/ttgxvar.c',
#    'phantom/libfreetype/ftinit.c',
#    'phantom/libfreetype/ftrfork.c',
#    'phantom/libfreetype/truetype.c',
#    'phantom/libfreetype/ftdebug.c',
#    'phantom/libfreetype/ftsmooth.c',
#    'phantom/libfreetype/afdummy.c',
#    'phantom/libfreetype/ftobjs.c',
#    'phantom/libfreetype/ftgloadr.c',
#    'phantom/libfreetype/ftbase.c',
#    'phantom/libfreetype/afglobal.c',
#    'phantom/libfreetype/afhints.c',
#    'phantom/libfreetype/ftdbgmem.c',
#    'phantom/libfreetype/sfobjs.c',
#    'phantom/libfreetype/sfdriver.c',
#    'phantom/libfreetype/afloader.c',
#    'phantom/libfreetype/autofit.c',
#    'phantom/libfreetype/fttrigon.c',
#    'phantom/libfreetype/ftnames.c',
#    'phantom/libfreetype/ttkern.c',
#    'phantom/libfreetype/ttobjs.c',
#    'phantom/libfreetype/afmodule.c',
#    'phantom/libfreetype/ttload.c',
#    'phantom/libfreetype/afangles.c',
#    'phantom/libfreetype/aflatin.c',
#    'phantom/libfreetype/ftcalc.c',
#    'phantom/libfreetype/ftgrays.c',
#    'phantom/libfreetype/ttdriver.c',
#    'phantom/libfreetype/ftglyph.c',
#    'phantom/libfreetype/ttpload.c']),
#  ('vm',
#   ['phantom/vm/exec.c',
#    'phantom/vm/syscall_io.c',
#    'phantom/vm/backtrace.c',
#    'phantom/vm/syscall_sync.c',
#    'phantom/vm/refdec.c',
#    'phantom/vm/gen_machindep.c',
#    'phantom/vm/syscall.c',
#    'phantom/vm/json_parse.c',
#    'phantom/vm/gdb.c',
#    'phantom/vm/vm_sleep.c',
#    'phantom/vm/e4c.c',
#    'phantom/vm/stacks.c',
#    'phantom/vm/wpool.c',
#    'phantom/vm/code.c',
#    'phantom/vm/root.c',
#    'phantom/vm/syscall_net_kernel.c',
#    'phantom/vm/vtest.c',
#    'phantom/vm/syscall_win.c',
#    'phantom/vm/create.c',
#    'phantom/vm/load_class.c',
#    'phantom/vm/ftype.c',
#    'phantom/vm/video_test.c',
#    'phantom/vm/syscall_tty.c',
#    'phantom/vm/object.c',
#    'phantom/vm/alloc.c',
#    'phantom/vm/syscall_net_windows.c',
#    'phantom/vm/find_class_file.c',
#    'phantom/vm/vm_threads.c',
#    'phantom/vm/jit.c',
#    'phantom/vm/internal.c',
#    'phantom/vm/bulk.c',
#    'phantom/vm/gc.c',
#    'phantom/vm/wpaint.c',
#    'phantom/vm/syscall_net.c',
#    'phantom/vm/directory.c',
#    'phantom/vm/sys/i_stat.c',
#    'phantom/vm/sys/i_udp.c',
#    'phantom/vm/sys/i_time.c',
#    'phantom/vm/sys/i_ui_control.c',
#    'phantom/vm/sys/i_io.c',
#    'phantom/vm/sys/i_ui_font.c',
#    'phantom/vm/sys/i_port.c',
#    'phantom/vm/sys/i_http.c',
#    'phantom/vm/sys/i_net.c']),
#  ('vm pvm_headless_screen', ['phantom/vm/headless_screen.c']),
#  ('isomem',
#   ['phantom/isomem/khash.c',
#    'phantom/isomem/udp_json.c',
#    'phantom/isomem/vm_cn_stats.c',
#    'phantom/isomem/unix_hal_sync.c',
#    'phantom/isomem/pool.c',
#    'phantom/isomem/unix_hal.c',
#    'phantom/isomem/temp_loader_misc.c',
#    'phantom/isomem/test_mem.c',
#    'phantom/isomem/hexdump.c',
#    'phantom/isomem/genode_credentials.c',
#    'phantom/isomem/genode_timer.c',
#    'phantom/isomem/vm_connect.c',
#    'phantom/isomem/genode_paging.c',
#    'phantom/isomem/test_switch.c',
#    'phantom/isomem/vm_load.c',
#    'phantom/isomem/fs_map.c',
#    'phantom/isomem/vm_map.c',
#    'phantom/isomem/hal_interrupts.c',
#    'phantom/isomem/vm_cn_fio.c',
#    'phantom/isomem/dpc.c',
#    'phantom/isomem/test_hdir.c',
#    'phantom/isomem/json_read.c',
#    'phantom/isomem/boot_cmd_line.c',
#    'phantom/isomem/genode_lprintf.c',
#    'phantom/isomem/main.c',
#    'phantom/isomem/genode_atomic.c',
#    'phantom/isomem/disk_struct.c',
#    'phantom/isomem/hashfunc.c',
#    'phantom/isomem/timedcall.c',
#    'phantom/isomem/genode_physalloc.c',
#    'phantom/isomem/pager.c',
#    'phantom/isomem/ide_io.c',
#    'phantom/isomem/genode_user_trap.c',
#    'phantom/isomem/hal.c',
#    'phantom/isomem/unix_threads.c',
#    'phantom/isomem/fsck.c',
#    'phantom/isomem/net_timer.c',
#    'phantom/isomem/unix_sys.c',
#    'phantom/isomem/disk.c',
#    'phantom/isomem/json_write.c',
#    'phantom/isomem/color.c',
#    'phantom/isomem/test_misc.c',
#    'phantom/isomem/pagelist.c',
#    'phantom/isomem/debug_misc.c',
#    'phantom/isomem/driver_pci_intel_etc.c',
#    'phantom/isomem/genode_kunix.c',
#    'phantom/isomem/unix_hal_unix.c',
#    'phantom/isomem/test_pool.c',
#    'phantom/isomem/vm_cn_url.c',
#    'phantom/isomem/genode_misc.c',
#    'phantom/isomem/disk_pool.c',
#    'phantom/isomem/physalloc.c',
#    'phantom/isomem/snap_sync.c',
#    'phantom/isomem/stats.c',
#    'phantom/isomem/genode_arch.c',
#    'phantom/isomem/syscalls_misc.c',
#    'phantom/isomem/time.c',
#    'phantom/isomem/test_disk.c',
#    'phantom/isomem/temp_wtty.c',
#    'phantom/isomem/vm_cn_timer.c',
#    'phantom/isomem/genode_time.c',
#    'phantom/isomem/amap.c',
#    'phantom/isomem/init_funcs.c',
#    'phantom/isomem/hal_physmem.c',
#    'phantom/isomem/test_amap.c',
#    'phantom/isomem/genode_gdb_cmd_stub.c',
#    'phantom/isomem/genode_net.c',
#    'phantom/isomem/genode_intrdisp.c',
#    'phantom/isomem/init.c',
#    'phantom/isomem/vm_cn_udp.c',
#    'phantom/isomem/genode_disk.c']),
#  ('isomem pvm_isomem', ['phantom/isomem/main.c'])]

# %%
for x in norm_files_per_section:
    print("---------- " + x[0])
    for f in x[1]:
        print("{} \\".format(f))
# Out:
# ---------- phantom vm-isomem
# ---------- gl
# phantom/gl/specbuf.c \
# phantom/gl/phantom_loop.c \
# phantom/gl/list.c \
# phantom/gl/error.c \
# phantom/gl/texture.c \
# phantom/gl/select.c \
# phantom/gl/init.c \
# phantom/gl/light.c \
# phantom/gl/arrays.c \
# phantom/gl/vertex.c \
# phantom/gl/oscontext.c \
# phantom/gl/image_util.c \
# phantom/gl/clip.c \
# phantom/gl/phantomdrvr.c \
# phantom/gl/api.c \
# phantom/gl/misc.c \
# phantom/gl/memory.c \
# phantom/gl/clear.c \
# phantom/gl/zdither.c \
# phantom/gl/msghandling.c \
# phantom/gl/ztriangle.c \
# phantom/gl/zline.c \
# phantom/gl/zmath.c \
# phantom/gl/zbuffer.c \
# phantom/gl/matrix.c \
# phantom/gl/texobj.c \
# phantom/gl/get.c \
# ---------- libtuned
# ---------- libphantom
# phantom/libphantom/console_color.c \
# phantom/libphantom/wired_spin.c \
# phantom/libphantom/udp_json_builder.c \
# phantom/libphantom/atoin.c \
# phantom/libphantom/init.c \
# phantom/libphantom/i_disk.c \
# phantom/libphantom/hashfunc.c \
# phantom/libphantom/udp_json.c \
# phantom/libphantom/pool.c \
# phantom/libphantom/hexdump.c \
# phantom/libphantom/json_read.c \
# phantom/libphantom/asn1.c \
# phantom/libphantom/atoln.c \
# phantom/libphantom/unicode2utf8.c \
# phantom/libphantom/disk_struct.c \
# phantom/libphantom/debug.c \
# phantom/libphantom/symtab.c \
# phantom/libphantom/jsmn.c \
# phantom/libphantom/stats.c \
# phantom/libphantom/json_write.c \
# phantom/libphantom/http.c \
# phantom/libphantom/wtty.c \
# phantom/libphantom/video/color.c \
# phantom/libphantom/lzma/LzmaDec.c \
# phantom/libphantom/lzma/simpleDecode.c \
# phantom/libphantom/unix/fname.c \
# ---------- libwin
# phantom/libwin/w_control.c \
# phantom/libwin/vid_read.c \
# phantom/libwin/scr_getset.c \
# phantom/libwin/w_decor.c \
# phantom/libwin/ev_window.c \
# phantom/libwin/w_getset.c \
# phantom/libwin/w_create.c \
# phantom/libwin/w_scroll.c \
# phantom/libwin/ev_main.c \
# phantom/libwin/vid_write.c \
# phantom/libwin/ev_mouse.c \
# phantom/libwin/bmp_pbm.c \
# phantom/libwin/rgba_bitblt_bits.c \
# phantom/libwin/scr_repaint.c \
# phantom/libwin/rgba_const.c \
# phantom/libwin/w_move_z.c \
# phantom/libwin/w_dump.c \
# phantom/libwin/rect_cmp.c \
# phantom/libwin/ctl_button.c \
# phantom/libwin/rgba_scroll.c \
# phantom/libwin/w_bg_win.c \
# phantom/libwin/w_lock.c \
# phantom/libwin/ctl_getset.c \
# phantom/libwin/ev_wtty.c \
# phantom/libwin/ev_put.c \
# phantom/libwin/vid_blt_wrap.c \
# phantom/libwin/w_truetype.c \
# phantom/libwin/scr_zbuf.c \
# phantom/libwin/w_resize.c \
# phantom/libwin/w_draw.c \
# phantom/libwin/w_repaint.c \
# phantom/libwin/w_menu.c \
# phantom/libwin/utf8proc.c \
# phantom/libwin/scr_painter.c \
# phantom/libwin/w_taskbar.c \
# phantom/libwin/ctl_create.c \
# phantom/libwin/scr_mouse_onoff.c \
# phantom/libwin/vid_mouse_pointer.c \
# phantom/libwin/rgba_zbmove.c \
# phantom/libwin/ctl_scrollbar.c \
# phantom/libwin/w_move_xy.c \
# phantom/libwin/ctl_text_field.c \
# phantom/libwin/w_replicate.c \
# phantom/libwin/w_blt.c \
# phantom/libwin/w_box.c \
# phantom/libwin/w_font.c \
# phantom/libwin/w_event_client.c \
# phantom/libwin/w_event_title.c \
# phantom/libwin/w_order.c \
# phantom/libwin/rgba_ablend_bits.c \
# phantom/libwin/w_update.c \
# phantom/libwin/ev_util.c \
# phantom/libwin/rgba_hsb.c \
# phantom/libwin/resources/OpenSans-Light.ttf.c \
# phantom/libwin/resources/button_next_green_full_alpha_x65.png.c \
# phantom/libwin/resources/RobotoMono-ThinItalic.ttf.c \
# phantom/libwin/resources/win_decor_dl.png.c \
# phantom/libwin/resources/vanilla_cream_rollup.png.c \
# phantom/libwin/resources/menu_normal_center.png.c \
# phantom/libwin/resources/checkbox_round_on_a_x30.png.c \
# phantom/libwin/resources/toolbar_icon_calendar_normal.png.c \
# phantom/libwin/resources/RobotoMono-Italic.ttf.c \
# phantom/libwin/resources/toolbar_icon_calendar_hover.png.c \
# phantom/libwin/resources/task_button.png.c \
# phantom/libwin/resources/OpenSans-Bold.ttf.c \
# phantom/libwin/resources/button_prev_green_alpha_x65.png.c \
# phantom/libwin/resources/power_button_sm.png.c \
# phantom/libwin/resources/icon_heart.png.c \
# phantom/libwin/resources/scrollbar_orange_bar_right.png.c \
# phantom/libwin/resources/win_decor_ul.png.c \
# phantom/libwin/resources/OpenSans-SemiBoldItalic.ttf.c \
# phantom/libwin/resources/toolbar_icon_shell_pressed.png.c \
# phantom/libwin/resources/checkbox_square_on_a_x30.png.c \
# phantom/libwin/resources/scrollbar_orange_bar_middle.png.c \
# phantom/libwin/resources/toolbar_icon_settings_pressed.png.c \
# phantom/libwin/resources/rollup_pressed.png.c \
# phantom/libwin/resources/menu_selected_center.png.c \
# phantom/libwin/resources/slide_switch_alpha_v31_off.png.c \
# phantom/libwin/resources/toolbar_icon_calendar_selected.png.c \
# phantom/libwin/resources/icon_key.png.c \
# phantom/libwin/resources/close_pressed.png.c \
# phantom/libwin/resources/OpenSans-SemiBold.ttf.c \
# phantom/libwin/resources/button_prev_green_full_alpha_x65.png.c \
# phantom/libwin/resources/scrollbar_bed_right.png.c \
# phantom/libwin/resources/slide_switch_off.png.c \
# phantom/libwin/resources/vanilla_cream_close.png.c \
# phantom/libwin/resources/scrollbar_orange_bar_left.png.c \
# phantom/libwin/resources/scrollbar_bed_middle_narrow.png.c \
# phantom/libwin/resources/OpenSans-ExtraBoldItalic.ttf.c \
# phantom/libwin/resources/RobotoMono-Light.ttf.c \
# phantom/libwin/resources/button_normal_alpha_x98_abw.png.c \
# phantom/libwin/resources/start_button_hover.png.c \
# phantom/libwin/resources/RobotoMono-LightItalic.ttf.c \
# phantom/libwin/resources/icon_conversation.png.c \
# phantom/libwin/resources/button_pressed_alpha_x98.png.c \
# phantom/libwin/resources/toolbar_icon_debug_hover.png.c \
# phantom/libwin/resources/win_decor_dr.png.c \
# phantom/libwin/resources/menu_normal_left.png.c \
# phantom/libwin/resources/text_field_icon_x160.png.c \
# phantom/libwin/resources/title_brown.png.c \
# phantom/libwin/resources/RobotoMono-Medium.ttf.c \
# phantom/libwin/resources/RobotoMono-Bold.ttf.c \
# phantom/libwin/resources/button_next_green_alpha_x65.png.c \
# phantom/libwin/resources/title_selected.png.c \
# phantom/libwin/resources/checkbox_round_off_a_x30.png.c \
# phantom/libwin/resources/small_popup_note.png.c \
# phantom/libwin/resources/title_green.png.c \
# phantom/libwin/resources/button_prev_alpha_x82.png.c \
# phantom/libwin/resources/icon_settings.png.c \
# phantom/libwin/resources/slide_switch_alpha_v31_on.png.c \
# phantom/libwin/resources/power_button_pressed_sm.png.c \
# phantom/libwin/resources/scroll_bar_green_handle.png.c \
# phantom/libwin/resources/title_violet.png.c \
# phantom/libwin/resources/menu_selected_left.png.c \
# phantom/libwin/resources/scrollbar_green_bar_right.png.c \
# phantom/libwin/resources/pin.png.c \
# phantom/libwin/resources/win_decor_ur.png.c \
# phantom/libwin/resources/toolbar_icon_selected.png.c \
# phantom/libwin/resources/scrollbar_green_bar_left.png.c \
# phantom/libwin/resources/OpenSans-BoldItalic.ttf.c \
# phantom/libwin/resources/notification_green_button.png.c \
# phantom/libwin/resources/toolbar_icon_calendar_pressed.png.c \
# phantom/libwin/resources/scrollbar_bed_middle.png.c \
# phantom/libwin/resources/OpenSans-Regular.ttf.c \
# phantom/libwin/resources/toolbar_icon_settings_normal.png.c \
# phantom/libwin/resources/rollup.png.c \
# phantom/libwin/resources/toolbar_icon_settings_hover.png.c \
# phantom/libwin/resources/toolbar_icon_debug_normal.png.c \
# phantom/libwin/resources/menu_normal_right.png.c \
# phantom/libwin/resources/checkbox_square_off_a_x30.png.c \
# phantom/libwin/resources/toolbar_icon_shell_normal.png.c \
# phantom/libwin/resources/button_center_white_for_green_alpha_x169.png.c \
# phantom/libwin/resources/RobotoMono-Thin.ttf.c \
# phantom/libwin/resources/RobotoMono-Regular.ttf.c \
# phantom/libwin/resources/button_hover_alpha_x98.png.c \
# phantom/libwin/resources/title_deselected.png.c \
# phantom/libwin/resources/button_next_alpha_x82.png.c \
# phantom/libwin/resources/toolbar_icon_shell_selected.png.c \
# phantom/libwin/resources/start_button_selected_w_key.png.c \
# phantom/libwin/resources/toolbar_icon_settings_selected.png.c \
# phantom/libwin/resources/text_field_x200.png.c \
# phantom/libwin/resources/start_button_selected.png.c \
# phantom/libwin/resources/button_normal_alpha_x98.png.c \
# phantom/libwin/resources/OpenSans-ExtraBold.ttf.c \
# phantom/libwin/resources/OpenSans-Italic.ttf.c \
# phantom/libwin/resources/menu_selected_right.png.c \
# phantom/libwin/resources/button_pressed_alpha_x98_abw.png.c \
# phantom/libwin/resources/scrollbar_green_bar_middle.png.c \
# phantom/libwin/resources/RobotoMono-MediumItalic.ttf.c \
# phantom/libwin/resources/close.png.c \
# phantom/libwin/resources/icon_text.png.c \
# phantom/libwin/resources/button_hover_alpha_x98_abw.png.c \
# phantom/libwin/resources/vanilla_background.png.c \
# phantom/libwin/resources/win_decor_ljoin.png.c \
# phantom/libwin/resources/toolbar_icon_debug_pressed.png.c \
# phantom/libwin/resources/RobotoMono-BoldItalic.ttf.c \
# phantom/libwin/resources/icon_home.png.c \
# phantom/libwin/resources/win_decor_rjoin.png.c \
# phantom/libwin/resources/icon_plus.png.c \
# phantom/libwin/resources/OpenSans-LightItalic.ttf.c \
# phantom/libwin/resources/start_button_normal.png.c \
# phantom/libwin/resources/toolbar_icon_shell_hover.png.c \
# phantom/libwin/resources/slide_switch_on.png.c \
# phantom/libwin/resources/icon_screen.png.c \
# phantom/libwin/resources/scrollbar_bed_left.png.c \
# phantom/libwin/fonts/drv_video_kolibri2.fnt.c \
# phantom/libwin/fonts/drv_video_8x16san.fnt.c \
# phantom/libwin/fonts/drv_video_8x16cou.fnt.c \
# phantom/libwin/fonts/drv_video_16x16.fnt.c \
# phantom/libwin/fonts/freebsd_font.c \
# phantom/libwin/fonts/drv_video_8x16med.fnt.c \
# phantom/libwin/fonts/gallant12x22.c \
# phantom/libwin/fonts/drv_video_8x16bro.fnt.c \
# phantom/libwin/fonts/drv_video_8x16rom.fnt.c \
# phantom/libwin/fonts/drv_video_8x16scr.fnt.c \
# phantom/libwin/fonts/drv_video_kolibri1.fnt.c \
# phantom/libwin/fonts/drv_video_8x16ant.fnt.c \
# phantom/libwin/fonts/8x11.fnt.c \
# phantom/libwin/mice/default_mouse.c \
# ---------- libfreetype
# phantom/libfreetype/sfnt.c \
# phantom/libfreetype/ttgload.c \
# phantom/libfreetype/ftutil.c \
# phantom/libfreetype/ttcmap.c \
# phantom/libfreetype/ftoutln.c \
# phantom/libfreetype/ttsbit.c \
# phantom/libfreetype/ftbitmap.c \
# phantom/libfreetype/ttpost.c \
# phantom/libfreetype/ftstream.c \
# phantom/libfreetype/ftsystem.c \
# phantom/libfreetype/smooth.c \
# phantom/libfreetype/ttgxvar.c \
# phantom/libfreetype/ftinit.c \
# phantom/libfreetype/ftrfork.c \
# phantom/libfreetype/truetype.c \
# phantom/libfreetype/ftdebug.c \
# phantom/libfreetype/ftsmooth.c \
# phantom/libfreetype/afdummy.c \
# phantom/libfreetype/ftobjs.c \
# phantom/libfreetype/ftgloadr.c \
# phantom/libfreetype/ftbase.c \
# phantom/libfreetype/afglobal.c \
# phantom/libfreetype/afhints.c \
# phantom/libfreetype/ftdbgmem.c \
# phantom/libfreetype/sfobjs.c \
# phantom/libfreetype/sfdriver.c \
# phantom/libfreetype/afloader.c \
# phantom/libfreetype/autofit.c \
# phantom/libfreetype/fttrigon.c \
# phantom/libfreetype/ftnames.c \
# phantom/libfreetype/ttkern.c \
# phantom/libfreetype/ttobjs.c \
# phantom/libfreetype/afmodule.c \
# phantom/libfreetype/ttload.c \
# phantom/libfreetype/afangles.c \
# phantom/libfreetype/aflatin.c \
# phantom/libfreetype/ftcalc.c \
# phantom/libfreetype/ftgrays.c \
# phantom/libfreetype/ttdriver.c \
# phantom/libfreetype/ftglyph.c \
# phantom/libfreetype/ttpload.c \
# ---------- vm
# phantom/vm/exec.c \
# phantom/vm/syscall_io.c \
# phantom/vm/backtrace.c \
# phantom/vm/syscall_sync.c \
# phantom/vm/refdec.c \
# phantom/vm/gen_machindep.c \
# phantom/vm/syscall.c \
# phantom/vm/json_parse.c \
# phantom/vm/gdb.c \
# phantom/vm/vm_sleep.c \
# phantom/vm/e4c.c \
# phantom/vm/stacks.c \
# phantom/vm/wpool.c \
# phantom/vm/code.c \
# phantom/vm/root.c \
# phantom/vm/syscall_net_kernel.c \
# phantom/vm/vtest.c \
# phantom/vm/syscall_win.c \
# phantom/vm/create.c \
# phantom/vm/load_class.c \
# phantom/vm/ftype.c \
# phantom/vm/video_test.c \
# phantom/vm/syscall_tty.c \
# phantom/vm/object.c \
# phantom/vm/alloc.c \
# phantom/vm/syscall_net_windows.c \
# phantom/vm/find_class_file.c \
# phantom/vm/vm_threads.c \
# phantom/vm/jit.c \
# phantom/vm/internal.c \
# phantom/vm/bulk.c \
# phantom/vm/gc.c \
# phantom/vm/wpaint.c \
# phantom/vm/syscall_net.c \
# phantom/vm/directory.c \
# phantom/vm/sys/i_stat.c \
# phantom/vm/sys/i_udp.c \
# phantom/vm/sys/i_time.c \
# phantom/vm/sys/i_ui_control.c \
# phantom/vm/sys/i_io.c \
# phantom/vm/sys/i_ui_font.c \
# phantom/vm/sys/i_port.c \
# phantom/vm/sys/i_http.c \
# phantom/vm/sys/i_net.c \
# ---------- vm pvm_headless_screen
# phantom/vm/headless_screen.c \
# ---------- isomem
# phantom/isomem/khash.c \
# phantom/isomem/udp_json.c \
# phantom/isomem/vm_cn_stats.c \
# phantom/isomem/unix_hal_sync.c \
# phantom/isomem/pool.c \
# phantom/isomem/unix_hal.c \
# phantom/isomem/temp_loader_misc.c \
# phantom/isomem/test_mem.c \
# phantom/isomem/hexdump.c \
# phantom/isomem/genode_credentials.c \
# phantom/isomem/genode_timer.c \
# phantom/isomem/vm_connect.c \
# phantom/isomem/genode_paging.c \
# phantom/isomem/test_switch.c \
# phantom/isomem/vm_load.c \
# phantom/isomem/fs_map.c \
# phantom/isomem/vm_map.c \
# phantom/isomem/hal_interrupts.c \
# phantom/isomem/vm_cn_fio.c \
# phantom/isomem/dpc.c \
# phantom/isomem/test_hdir.c \
# phantom/isomem/json_read.c \
# phantom/isomem/boot_cmd_line.c \
# phantom/isomem/genode_lprintf.c \
# phantom/isomem/main.c \
# phantom/isomem/genode_atomic.c \
# phantom/isomem/disk_struct.c \
# phantom/isomem/hashfunc.c \
# phantom/isomem/timedcall.c \
# phantom/isomem/genode_physalloc.c \
# phantom/isomem/pager.c \
# phantom/isomem/ide_io.c \
# phantom/isomem/genode_user_trap.c \
# phantom/isomem/hal.c \
# phantom/isomem/unix_threads.c \
# phantom/isomem/fsck.c \
# phantom/isomem/net_timer.c \
# phantom/isomem/unix_sys.c \
# phantom/isomem/disk.c \
# phantom/isomem/json_write.c \
# phantom/isomem/color.c \
# phantom/isomem/test_misc.c \
# phantom/isomem/pagelist.c \
# phantom/isomem/debug_misc.c \
# phantom/isomem/driver_pci_intel_etc.c \
# phantom/isomem/genode_kunix.c \
# phantom/isomem/unix_hal_unix.c \
# phantom/isomem/test_pool.c \
# phantom/isomem/vm_cn_url.c \
# phantom/isomem/genode_misc.c \
# phantom/isomem/disk_pool.c \
# phantom/isomem/physalloc.c \
# phantom/isomem/snap_sync.c \
# phantom/isomem/stats.c \
# phantom/isomem/genode_arch.c \
# phantom/isomem/syscalls_misc.c \
# phantom/isomem/time.c \
# phantom/isomem/test_disk.c \
# phantom/isomem/temp_wtty.c \
# phantom/isomem/vm_cn_timer.c \
# phantom/isomem/genode_time.c \
# phantom/isomem/amap.c \
# phantom/isomem/init_funcs.c \
# phantom/isomem/hal_physmem.c \
# phantom/isomem/test_amap.c \
# phantom/isomem/genode_gdb_cmd_stub.c \
# phantom/isomem/genode_net.c \
# phantom/isomem/genode_intrdisp.c \
# phantom/isomem/init.c \
# phantom/isomem/vm_cn_udp.c \
# phantom/isomem/genode_disk.c \
# ---------- isomem pvm_isomem
# phantom/isomem/main.c \

# %%
for x in norm_files_per_section:
    print("---------- " + x[0])
# Out:
# ---------- phantom/gl
# ---------- phantom/libtuned
# ---------- phantom/libphantom
# ---------- phantom/libwin
# ---------- phantom/libfreetype
# ---------- phantom/libc
# ---------- phantom/vm pvm_headless
